# %% [markdown]
# # Politician Analysis and Results
#
# This file completes the data analysis and results sections of Homework 2.

# %%
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import pandas as pd
import numpy as np

# %% [markdown]
# Read in the data first.

# %%
data = pd.read_csv('data/wp_politicians_by_country.csv')
data.head()
# Out:
#            article_title      country article_quality  revision_id  \
# 0        Shahjahan Noori  Afghanistan            "GA"   1099689043
# 1  Abdul Ghafar Lakanwal  Afghanistan         "Start"    943562276
# 2         Majah Ha Adrif  Afghanistan         "Start"    852404094
# 3      Haroon al-Afghani  Afghanistan             "B"   1095102390
# 4            Tayyab Agha  Afghanistan         "Start"   1104998382
#
#    population      region
# 0        41.1  SOUTH ASIA
# 1        41.1  SOUTH ASIA
# 2        41.1  SOUTH ASIA
# 3        41.1  SOUTH ASIA
# 4        41.1  SOUTH ASIA

# %% [markdown]
# First we will need to transform the data to perform the analysis. This will involve creating a column to determine whether the article quality is high or not.

# %%
# Method to make a column to signify if article is high quality.
def is_high_quality (row):
    if row in ['"FA"', '"GA"']:
        return 1
    else:
        return 0

# %%
# Adding the high_quality column
data['high_quality'] = data.apply(lambda x: is_high_quality(x['article_quality']), axis=1)
data.head()
# Out:
#            article_title      country article_quality  revision_id  \
# 0        Shahjahan Noori  Afghanistan            "GA"   1099689043
# 1  Abdul Ghafar Lakanwal  Afghanistan         "Start"    943562276
# 2         Majah Ha Adrif  Afghanistan         "Start"    852404094
# 3      Haroon al-Afghani  Afghanistan             "B"   1095102390
# 4            Tayyab Agha  Afghanistan         "Start"   1104998382
#
#    population      region  high_quality
# 0        41.1  SOUTH ASIA             1
# 1        41.1  SOUTH ASIA             0
# 2        41.1  SOUTH ASIA             0
# 3        41.1  SOUTH ASIA             0
# 4        41.1  SOUTH ASIA             0

# %% [markdown]
# Now we will aggregate the data by country and get total number of articles per capita and total number of high quality articles per capita.

# %%
# Creating the country aggregation
agg_data = data.groupby(['country', 'population', 'region']).agg({'high_quality': 'sum', 'article_title': 'count'})
agg_data = agg_data.reset_index()
agg_data['articles_per_population'] = agg_data['article_title']/agg_data['population']
agg_data['hq_articles_per_population'] = agg_data['high_quality']/agg_data['population']
agg_data = agg_data.drop(['high_quality', 'article_title'], axis=1)
agg_data.head()
# Out:
#        country  population           region  articles_per_population  \
# 0  Afghanistan        41.1       SOUTH ASIA                 2.871046
# 1      Albania         2.8  SOUTHERN EUROPE                29.642857
# 2      Algeria        44.9  NORTHERN AFRICA                 0.757238
# 3      Andorra         0.1  SOUTHERN EUROPE               100.000000
# 4       Angola        35.6    MIDDLE AFRICA                 1.179775
#
#    hq_articles_per_population
# 0                    0.145985
# 1                    2.142857
# 2                    0.000000
# 3                   20.000000
# 4                    0.000000

# %% [markdown]
# Now we will aggregate the data by region and get total number of articles per capita and total number of high quality articles per capita.

# %%
# Bring back the population data for region populations
world_pop = pd.read_csv('population_by_country_2022.csv')

# %%
# Creating the region aggregation
reg_agg_data = data.groupby(['region']).agg({'high_quality': 'sum', 'article_title': 'count'})
reg_agg_data = reg_agg_data.reset_index()
reg_agg_data = reg_agg_data.merge(world_pop, how='left', left_on='region', right_on='Geography')
reg_agg_data = reg_agg_data.rename(columns={'Population (millions)': 'population'})
reg_agg_data['articles_per_population'] = reg_agg_data['article_title']/reg_agg_data['population']
reg_agg_data['hq_articles_per_population'] = reg_agg_data['high_quality']/reg_agg_data['population']
reg_agg_data = reg_agg_data.drop(['high_quality', 'article_title', 'Geography'], axis=1)
reg_agg_data.head(20)
# Out:
#              region  population  articles_per_population  \
# 0         CARIBBEAN        44.0                 4.568182
# 1   CENTRAL AMERICA       178.0                 1.095506
# 2      CENTRAL ASIA        78.0                 1.358974
# 3         EAST ASIA      1674.0                 0.146356
# 4    EASTERN AFRICA       473.0                 1.374207
# 5    EASTERN EUROPE       287.0                 2.564460
# 6     MIDDLE AFRICA       196.0                 1.035714
# 7   NORTHERN AFRICA       251.0                 0.904382
# 8   NORTHERN EUROPE       107.0                 2.448598
# 9           OCEANIA        44.0                 1.954545
# 10    SOUTH AMERICA       434.0                 1.329493
# 11       SOUTH ASIA      2008.0                 0.322709
# 12   SOUTHEAST ASIA       676.0                 0.609467
# 13  SOUTHERN AFRICA        69.0                 1.710145
# 14  SOUTHERN EUROPE       151.0                 5.894040
# 15   WESTERN AFRICA       430.0                 1.323256
# 16     WESTERN ASIA       294.0                 2.333333
# 17   WESTERN EUROPE       197.0                 3.548223
#
#     hq_articles_per_population
# 0                     0.181818
# 1                     0.056180
# 2                     0.038462
# 3                     0.009558
# 4                     0.031712
# 5                     0.135889
# 6                     0.025510
# 7                     0.023904
# 8                     0.074766
# 9                     0.045455
# 10                    0.029954
# 11                    0.011454
# 12                    0.035503
# 13                    0.057971
# 14                    0.304636
# 15                    0.030233
# 16                    0.095238
# 17                    0.111675

# %% [markdown]
# ## Now we can get the results.
#
# First off the 10 countries with the most articles per capita. There are six countries without population values so we will exclude them from this analysis.

# %%
# Not using .head() to skip the countries without population
agg_data.sort_values(by='articles_per_population', ascending=False, ignore_index=True).loc[6:15]
# Out:
#                            country  population           region  \
# 6              Antigua and Barbuda         0.1        CARIBBEAN
# 7   Federated States of Micronesia         0.1          OCEANIA
# 8                          Andorra         0.1  SOUTHERN EUROPE
# 9                         Barbados         0.3        CARIBBEAN
# 10                Marshall Islands         0.1          OCEANIA
# 11                      Montenegro         0.6  SOUTHERN EUROPE
# 12                      Seychelles         0.1   EASTERN AFRICA
# 13                      Luxembourg         0.7   WESTERN EUROPE
# 14                          Bhutan         0.8       SOUTH ASIA
# 15                         Grenada         0.1        CARIBBEAN
#
#     articles_per_population  hq_articles_per_population
# 6                170.000000                         0.0
# 7                130.000000                         0.0
# 8                100.000000                        20.0
# 9                 93.333333                         0.0
# 10                90.000000                         0.0
# 11                60.000000                         5.0
# 12                60.000000                         0.0
# 13                52.857143                         0.0
# 14                51.250000                         0.0
# 15                50.000000                         0.0

# %% [markdown]
# Now the 10 countries with the least articles per capita.

# %%
agg_data.sort_values(by='articles_per_population').head(10)
# Out:
#           country  population           region  articles_per_population  \
# 32          China      1436.6        EAST ASIA                 0.001392
# 106        Mexico       127.5  CENTRAL AMERICA                 0.007843
# 140  Saudi Arabia        36.7     WESTERN ASIA                 0.081744
# 134       Romania        19.0   EASTERN EUROPE                 0.105263
# 73          India      1417.2       SOUTH ASIA                 0.125600
# 153     Sri Lanka        22.4       SOUTH ASIA                 0.133929
# 48          Egypt       103.5  NORTHERN AFRICA                 0.135266
# 53       Ethiopia       123.4   EASTERN AFRICA                 0.202593
# 161        Taiwan        23.2        EAST ASIA                 0.215517
# 180       Vietnam        99.4   SOUTHEAST ASIA                 0.271630
#
#      hq_articles_per_population
# 32                     0.000000
# 106                    0.000000
# 140                    0.054496
# 134                    0.105263
# 73                     0.004234
# 153                    0.000000
# 48                     0.000000
# 53                     0.024311
# 161                    0.000000
# 180                    0.020121

# %% [markdown]
# Now the 10 countries with the most high quality articles per capita. Again, there is a country without population so we will exclude it from this analysis.

# %%
# Not using .head() to skip the country without population
agg_data.sort_values(by='hq_articles_per_population', ascending=False, ignore_index=True).loc[1:10]
# Out:
#                   country  population           region  \
# 1                 Andorra         0.1  SOUTHERN EUROPE
# 2              Montenegro         0.6  SOUTHERN EUROPE
# 3                 Albania         2.8  SOUTHERN EUROPE
# 4                Suriname         0.6    SOUTH AMERICA
# 5      Bosnia-Herzegovina         3.4  SOUTHERN EUROPE
# 6               Lithuania         2.8  NORTHERN EUROPE
# 7                 Croatia         3.8  SOUTHERN EUROPE
# 8                Slovenia         2.1  SOUTHERN EUROPE
# 9   Palestinian Territory         5.4     WESTERN ASIA
# 10                  Gabon         2.4    MIDDLE AFRICA
#
#     articles_per_population  hq_articles_per_population
# 1                100.000000                   20.000000
# 2                 60.000000                    5.000000
# 3                 29.642857                    2.142857
# 4                 38.333333                    1.666667
# 5                 15.294118                    1.470588
# 6                 26.785714                    1.071429
# 7                 14.210526                    1.052632
# 8                 20.476190                    0.952381
# 9                 13.148148                    0.925926
# 10                 2.500000                    0.833333

# %% [markdown]
# Now the 10 countries with the least high quality articles per capita. There are actually 86 countries with no high quality articles. The below two queries display all countries without a high quality article.

# %%
agg_data.sort_values(by='hq_articles_per_population', ignore_index=True).head(50)
# Out:
#                            country  population           region  \
# 0                             Laos         7.5   SOUTHEAST ASIA
# 1                         Mongolia         3.4        EAST ASIA
# 2                          Moldova         3.5   EASTERN EUROPE
# 3                           Mexico       127.5  CENTRAL AMERICA
# 4                 Marshall Islands         0.1          OCEANIA
# 5                            Malta         0.5  SOUTHERN EUROPE
# 6                         Maldives         0.6       SOUTH ASIA
# 7                           Malawi        20.4   EASTERN AFRICA
# 8                       Madagascar        29.6   EASTERN AFRICA
# 9                       Luxembourg         0.7   WESTERN EUROPE
# 10                         Liberia         5.3   WESTERN AFRICA
# 11                         Lesotho         2.3  SOUTHERN AFRICA
# 12                      Mozambique        33.0   EASTERN AFRICA
# 13                          Latvia         1.9  NORTHERN EUROPE
# 14                          Kuwait         4.1     WESTERN ASIA
# 15                         Jamaica         2.8        CARIBBEAN
# 16                           Italy        58.9  SOUTHERN EUROPE
# 17                          Israel         9.5     WESTERN ASIA
# 18                         Iceland         0.4  NORTHERN EUROPE
# 19                        Honduras         9.6  CENTRAL AMERICA
# 20                          Guyana         0.8    SOUTH AMERICA
# 21                   Guinea-Bissau         2.1   WESTERN AFRICA
# 22                         Grenada         0.1        CARIBBEAN
# 23                          Greece        10.6  SOUTHERN EUROPE
# 24                           Ghana        33.5   WESTERN AFRICA
# 25                          Zambia        20.0   EASTERN AFRICA
# 26                         Namibia         2.6  SOUTHERN AFRICA
# 27                       Nicaragua         6.7  CENTRAL AMERICA
# 28                           Niger        26.2   WESTERN AFRICA
# 29                       Venezuela        28.3    SOUTH AMERICA
# 30                         Vanuatu         0.3          OCEANIA
# 31                      Uzbekistan        35.6     CENTRAL ASIA
# 32                    Turkmenistan         6.4     CENTRAL ASIA
# 33                          Turkey        85.2     WESTERN ASIA
# 34             Trinidad and Tobago         1.4        CARIBBEAN
# 35                           Tonga         0.1          OCEANIA
# 36                            Togo         8.8   WESTERN AFRICA
# 37                     Timor-Leste         1.3   SOUTHEAST ASIA
# 38                        Tanzania        65.5   EASTERN AFRICA
# 39                      Tajikistan        10.0     CENTRAL ASIA
# 40                          Taiwan        23.2        EAST ASIA
# 41  St. Vincent and the Grenadines         0.1        CARIBBEAN
# 42                 St. Kitts-Nevis         0.1        CARIBBEAN
# 43                       Sri Lanka        22.4       SOUTH ASIA
# 44                 Solomon Islands         0.7          OCEANIA
# 45                       Singapore         5.5   SOUTHEAST ASIA
# 46                    Sierra Leone         8.7   WESTERN AFRICA
# 47                      Seychelles         0.1   EASTERN AFRICA
# 48                           Samoa         0.2          OCEANIA
# 49                     Saint Lucia         0.2        CARIBBEAN
#
#     articles_per_population  hq_articles_per_population
# 0                  0.800000                         0.0
# 1                  3.235294                         0.0
# 2                  5.142857                         0.0
# 3                  0.007843                         0.0
# 4                 90.000000                         0.0
# 5                 14.000000                         0.0
# 6                 36.666667                         0.0
# 7                  0.343137                         0.0
# 8                  1.013514                         0.0
# 9                 52.857143                         0.0
# 10                 4.150943                         0.0
# 11                 1.739130                         0.0
# 12                 0.272727                         0.0
# 13                 4.736842                         0.0
# 14                 2.682927                         0.0
# 15                 6.785714                         0.0
# 16                 2.665535                         0.0
# 17                 0.526316                         0.0
# 18                32.500000                         0.0
# 19                 1.770833                         0.0
# 20                22.500000                         0.0
# 21                 3.809524                         0.0
# 22                50.000000                         0.0
# 23                 4.716981                         0.0
# 24                 1.164179                         0.0
# 25                 0.650000                         0.0
# 26                 6.538462                         0.0
# 27                 1.940299                         0.0
# 28                 0.648855                         0.0
# 29                 2.190813                         0.0
# 30                16.666667                         0.0
# 31                 0.477528                         0.0
# 32                 1.250000                         0.0
# 33                 0.657277                         0.0
# 34                11.428571                         0.0
# 35                30.000000                         0.0
# 36                 1.704545                         0.0
# 37                13.076923                         0.0
# 38                 0.412214                         0.0
# 39                 1.500000                         0.0
# 40                 0.215517                         0.0
# 41                30.000000                         0.0
# 42                30.000000                         0.0
# 43                 0.133929                         0.0
# 44                17.142857                         0.0
# 45                 0.545455                         0.0
# 46                 3.333333                         0.0
# 47                60.000000                         0.0
# 48                35.000000                         0.0
# 49                 5.000000                         0.0

# %%
agg_data.sort_values(by='hq_articles_per_population', ignore_index=True).loc[50:85]
# Out:
#                            country  population           region  \
# 50                           Qatar         2.7     WESTERN ASIA
# 51                        Paraguay         6.8    SOUTH AMERICA
# 52                            Oman         4.6     WESTERN ASIA
# 53                 North Macedonia         1.8  SOUTHERN EUROPE
# 54                          Gambia         2.7   WESTERN AFRICA
# 55                         Finland         5.6  NORTHERN EUROPE
# 56                        Zimbabwe        16.3   EASTERN AFRICA
# 57                      Bangladesh       171.2       SOUTH ASIA
# 58                       Argentina        46.2    SOUTH AMERICA
# 59                         Austria         9.0   WESTERN EUROPE
# 60                         Denmark         5.9  NORTHERN EUROPE
# 61                          Cyprus         1.3     WESTERN ASIA
# 62                         Bahamas         0.4        CARIBBEAN
# 63                         Bahrain         1.5     WESTERN ASIA
# 64                   Cote d'Ivoire        28.2   WESTERN AFRICA
# 65                        Barbados         0.3        CARIBBEAN
# 66                        Djibouti         1.1   EASTERN AFRICA
# 67                Congo, Dem. Rep.        99.0    MIDDLE AFRICA
# 68                         Comoros         0.8   EASTERN AFRICA
# 69                           China      1436.6        EAST ASIA
# 70                            Chad        17.7    MIDDLE AFRICA
# 71                      Cape Verde         0.6   WESTERN AFRICA
# 72                          Belize         0.4  CENTRAL AMERICA
# 73                            Fiji         0.9          OCEANIA
# 74                          Bhutan         0.8       SOUTH ASIA
# 75                        Botswana         2.6  SOUTHERN AFRICA
# 76                           Congo         6.0    MIDDLE AFRICA
# 77                        Dominica         0.1        CARIBBEAN
# 78                          Brazil       214.8    SOUTH AMERICA
# 79                         Algeria        44.9  NORTHERN AFRICA
# 80                         Eritrea         3.7   EASTERN AFRICA
# 81             Antigua and Barbuda         0.1        CARIBBEAN
# 82  Federated States of Micronesia         0.1          OCEANIA
# 83               Equatorial Guinea         1.7    MIDDLE AFRICA
# 84                           Egypt       103.5  NORTHERN AFRICA
# 85                          Angola        35.6    MIDDLE AFRICA
#
#     articles_per_population  hq_articles_per_population
# 50                 5.925926                         0.0
# 51                 2.352941                         0.0
# 52                 1.956522                         0.0
# 53                15.555556                         0.0
# 54                 7.777778                         0.0
# 55                 7.142857                         0.0
# 56                 3.865031                         0.0
# 57                 0.327103                         0.0
# 58                 1.168831                         0.0
# 59                 9.555556                         0.0
# 60                 2.203390                         0.0
# 61                10.000000                         0.0
# 62                 7.500000                         0.0
# 63                24.000000                         0.0
# 64                 0.390071                         0.0
# 65                93.333333                         0.0
# 66                10.909091                         0.0
# 67                 0.515152                         0.0
# 68                25.000000                         0.0
# 69                 0.001392                         0.0
# 70                 1.186441                         0.0
# 71                16.666667                         0.0
# 72                 7.500000                         0.0
# 73                15.555556                         0.0
# 74                51.250000                         0.0
# 75                 4.230769                         0.0
# 76                 5.500000                         0.0
# 77                40.000000                         0.0
# 78                 0.414339                         0.0
# 79                 0.757238                         0.0
# 80                 3.243243                         0.0
# 81               170.000000                         0.0
# 82               130.000000                         0.0
# 83                 7.058824                         0.0
# 84                 0.135266                         0.0
# 85                 1.179775                         0.0

# %% [markdown]
# Now the regions ordered by number of articles per population.

# %%
reg_agg_data.sort_values(by='articles_per_population', ascending=False)
# Out:
#              region  population  articles_per_population  \
# 14  SOUTHERN EUROPE       151.0                 5.894040
# 0         CARIBBEAN        44.0                 4.568182
# 17   WESTERN EUROPE       197.0                 3.548223
# 5    EASTERN EUROPE       287.0                 2.564460
# 8   NORTHERN EUROPE       107.0                 2.448598
# 16     WESTERN ASIA       294.0                 2.333333
# 9           OCEANIA        44.0                 1.954545
# 13  SOUTHERN AFRICA        69.0                 1.710145
# 4    EASTERN AFRICA       473.0                 1.374207
# 2      CENTRAL ASIA        78.0                 1.358974
# 10    SOUTH AMERICA       434.0                 1.329493
# 15   WESTERN AFRICA       430.0                 1.323256
# 1   CENTRAL AMERICA       178.0                 1.095506
# 6     MIDDLE AFRICA       196.0                 1.035714
# 7   NORTHERN AFRICA       251.0                 0.904382
# 12   SOUTHEAST ASIA       676.0                 0.609467
# 11       SOUTH ASIA      2008.0                 0.322709
# 3         EAST ASIA      1674.0                 0.146356
#
#     hq_articles_per_population
# 14                    0.304636
# 0                     0.181818
# 17                    0.111675
# 5                     0.135889
# 8                     0.074766
# 16                    0.095238
# 9                     0.045455
# 13                    0.057971
# 4                     0.031712
# 2                     0.038462
# 10                    0.029954
# 15                    0.030233
# 1                     0.056180
# 6                     0.025510
# 7                     0.023904
# 12                    0.035503
# 11                    0.011454
# 3                     0.009558

# %% [markdown]
# Finally, regions ordered by number of high quality articles per population

# %%
reg_agg_data.sort_values(by='hq_articles_per_population', ascending=False)
# Out:
#              region  population  articles_per_population  \
# 14  SOUTHERN EUROPE       151.0                 5.894040
# 0         CARIBBEAN        44.0                 4.568182
# 5    EASTERN EUROPE       287.0                 2.564460
# 17   WESTERN EUROPE       197.0                 3.548223
# 16     WESTERN ASIA       294.0                 2.333333
# 8   NORTHERN EUROPE       107.0                 2.448598
# 13  SOUTHERN AFRICA        69.0                 1.710145
# 1   CENTRAL AMERICA       178.0                 1.095506
# 9           OCEANIA        44.0                 1.954545
# 2      CENTRAL ASIA        78.0                 1.358974
# 12   SOUTHEAST ASIA       676.0                 0.609467
# 4    EASTERN AFRICA       473.0                 1.374207
# 15   WESTERN AFRICA       430.0                 1.323256
# 10    SOUTH AMERICA       434.0                 1.329493
# 6     MIDDLE AFRICA       196.0                 1.035714
# 7   NORTHERN AFRICA       251.0                 0.904382
# 11       SOUTH ASIA      2008.0                 0.322709
# 3         EAST ASIA      1674.0                 0.146356
#
#     hq_articles_per_population
# 14                    0.304636
# 0                     0.181818
# 5                     0.135889
# 17                    0.111675
# 16                    0.095238
# 8                     0.074766
# 13                    0.057971
# 1                     0.056180
# 9                     0.045455
# 2                     0.038462
# 12                    0.035503
# 4                     0.031712
# 15                    0.030233
# 10                    0.029954
# 6                     0.025510
# 7                     0.023904
# 11                    0.011454
# 3                     0.009558
